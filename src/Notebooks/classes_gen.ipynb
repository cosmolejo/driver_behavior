# %%
# !pwd
# Out:
# /home/antares/driver_behavior/src/Notebooks

# %%
import pandas as pd

df = pd.read_csv('anotaciones_completas.csv')
df
# Out:
#                                             Ruta_Archivo  \
# 0      /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 1      /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 2      /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 3      /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 4      /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# ...                                                  ...
# 39304  /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 39305  /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 39306  /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 39307  /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 39308  /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
#
#                                          Video_Origen  ID_Accion  \
# 0       gA_1_s1_2019-03-08T09;31;15+01;00_distraction          0
# 1       gA_1_s1_2019-03-08T09;31;15+01;00_distraction          0
# 2       gA_1_s1_2019-03-08T09;31;15+01;00_distraction          0
# 3       gA_1_s1_2019-03-08T09;31;15+01;00_distraction          0
# 4       gA_1_s1_2019-03-08T09;31;15+01;00_distraction          0
# ...                                               ...        ...
# 39304  gZ_37_s4_2019-04-03T15;40;42+02;00_distraction         17
# 39305  gZ_37_s4_2019-04-03T15;40;42+02;00_distraction         17
# 39306  gZ_37_s4_2019-04-03T15;40;42+02;00_distraction         17
# 39307  gZ_37_s4_2019-04-03T15;40;42+02;00_distraction         17
# 39308  gZ_37_s4_2019-04-03T15;40;42+02;00_distraction         17
#
#                          Actividad  Frame_Inicio  Frame_Fin
# 0        gaze_on_road/looking_road             0         33
# 1        gaze_on_road/looking_road            44        516
# 2        gaze_on_road/looking_road           547        553
# 3        gaze_on_road/looking_road           579        603
# 4        gaze_on_road/looking_road           625        633
# ...                            ...           ...        ...
# 39304  driver_actions/unclassified         12420      12461
# 39305  driver_actions/unclassified         13876      13901
# 39306  driver_actions/unclassified         14634      14679
# 39307  driver_actions/unclassified         15553      15647
# 39308  driver_actions/unclassified         15779      15832
#
# [39309 rows x 6 columns]

# %%
import numpy as np

np.unique(df.Actividad)
# Out:
# array(['blinks/blinking', 'driver_actions/change_gear',
#        'driver_actions/drinking', 'driver_actions/hair_and_makeup',
#        'driver_actions/phonecall_left', 'driver_actions/phonecall_right',
#        'driver_actions/radio', 'driver_actions/reach_backseat',
#        'driver_actions/reach_side', 'driver_actions/safe_drive',
#        'driver_actions/standstill_or_waiting',
#        'driver_actions/talking_to_passenger',
#        'driver_actions/texting_left', 'driver_actions/texting_right',
#        'driver_actions/unclassified', 'eyes_state/close',
#        'eyes_state/closing', 'eyes_state/open', 'eyes_state/opening',
#        'eyes_state/undefined', 'gaze_on_road/looking_road',
#        'gaze_on_road/not_looking_road', 'hand_on_gear/hand_on_gear',
#        'hands_using_wheel/both', 'hands_using_wheel/none',
#        'hands_using_wheel/only_left', 'hands_using_wheel/only_right',
#        'talking/talking', 'yawning/Yawning with hand',
#        'yawning/Yawning without hand'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=df, y='Actividad')
# Out:
# <Axes: xlabel='Count', ylabel='Actividad'>

# %%
df['Actividad_'] = df.Actividad.apply(lambda x: x.split('/')[-1])

sns.histplot(data=df, y='Actividad_')
# Out:
# <Axes: xlabel='Count', ylabel='Actividad_'>

# %%
np.unique(df.Actividad)
# Out:
# array(['blinks/blinking', 'driver_actions/change_gear',
#        'driver_actions/drinking', 'driver_actions/hair_and_makeup',
#        'driver_actions/phonecall_left', 'driver_actions/phonecall_right',
#        'driver_actions/radio', 'driver_actions/reach_backseat',
#        'driver_actions/reach_side', 'driver_actions/safe_drive',
#        'driver_actions/standstill_or_waiting',
#        'driver_actions/talking_to_passenger',
#        'driver_actions/texting_left', 'driver_actions/texting_right',
#        'driver_actions/unclassified', 'eyes_state/close',
#        'eyes_state/closing', 'eyes_state/open', 'eyes_state/opening',
#        'eyes_state/undefined', 'gaze_on_road/looking_road',
#        'gaze_on_road/not_looking_road', 'hand_on_gear/hand_on_gear',
#        'hands_using_wheel/both', 'hands_using_wheel/none',
#        'hands_using_wheel/only_left', 'hands_using_wheel/only_right',
#        'talking/talking', 'yawning/Yawning with hand',
#        'yawning/Yawning without hand'], dtype=object)

# %%
clases = ['blinks/blinking',
       'driver_actions/drinking', 'driver_actions/hair_and_makeup',
       'driver_actions/phonecall_left', 'driver_actions/phonecall_right',
       'driver_actions/radio', 'driver_actions/reach_backseat',
       'driver_actions/reach_side', 'driver_actions/safe_drive',
       'driver_actions/talking_to_passenger',
       'driver_actions/texting_left', 'driver_actions/texting_right', 'eyes_state/close',
       'eyes_state/closing', 'eyes_state/open', 'eyes_state/opening',
       'talking/talking', 'yawning/Yawning with hand',
       'yawning/Yawning without hand']

df = df.query(f'Actividad in {clases}')
df
# Out:
#                                             Ruta_Archivo  \
# 81     /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 82     /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 83     /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 84     /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 85     /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# ...                                                  ...
# 39286  /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 39287  /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 39288  /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 39289  /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
# 39290  /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
#
#                                          Video_Origen  ID_Accion  \
# 81      gA_1_s1_2019-03-08T09;31;15+01;00_distraction          2
# 82      gA_1_s1_2019-03-08T09;31;15+01;00_distraction          2
# 83      gA_1_s1_2019-03-08T09;31;15+01;00_distraction          2
# 84      gA_1_s1_2019-03-08T09;31;15+01;00_distraction          2
# 85      gA_1_s1_2019-03-08T09;31;15+01;00_distraction          2
# ...                                               ...        ...
# 39286  gZ_37_s4_2019-04-03T15;40;42+02;00_distraction         14
# 39287  gZ_37_s4_2019-04-03T15;40;42+02;00_distraction         14
# 39288  gZ_37_s4_2019-04-03T15;40;42+02;00_distraction         15
# 39289  gZ_37_s4_2019-04-03T15;40;42+02;00_distraction         15
# 39290  gZ_37_s4_2019-04-03T15;40;42+02;00_distraction         15
#
#                             Actividad  Frame_Inicio  Frame_Fin  \
# 81                    talking/talking           177        315
# 82                    talking/talking           335        343
# 83                    talking/talking          2094       2162
# 84                    talking/talking          2190       2291
# 85                    talking/talking          2350       2363
# ...                               ...           ...        ...
# 39286       driver_actions/reach_side         15474      15552
# 39287       driver_actions/reach_side         15833      15903
# 39288  driver_actions/hair_and_makeup           610        913
# 39289  driver_actions/hair_and_makeup          7602       7857
# 39290  driver_actions/hair_and_makeup         15061      15329
#
#             Actividad_
# 81             talking
# 82             talking
# 83             talking
# 84             talking
# 85             talking
# ...                ...
# 39286       reach_side
# 39287       reach_side
# 39288  hair_and_makeup
# 39289  hair_and_makeup
# 39290  hair_and_makeup
#
# [18156 rows x 7 columns]

# %%
clas_dict = {'blinks/blinking': 'drowsiness',
       'driver_actions/drinking' : 'eating/drinking', 
       'driver_actions/hair_and_makeup' : 'makeup', 
       'driver_actions/phonecall_left' : 'devices', 
       'driver_actions/phonecall_right': 'devices',
       'driver_actions/radio': 'devices',
       'driver_actions/reach_backseat' : 'reaching',
       'driver_actions/reach_side': 'reaching',
       'driver_actions/safe_drive': 'safe',
       'driver_actions/talking_to_passenger': 'talking_',
       'driver_actions/texting_left': 'devices', 
       'driver_actions/texting_right': 'devices', 
       'eyes_state/close': 'drowsiness_',
       'eyes_state/closing': 'drowsiness_', 
       'eyes_state/open': 'drowsiness_', 
       'eyes_state/opening': 'drowsiness_',
       'talking/talking': 'talking', 
       'yawning/Yawning with hand': 'drowsiness',
       'yawning/Yawning without hand': 'drowsiness'}

df['class'] = df.Actividad.apply(lambda x: clas_dict[x])
df['class']
# Out:
# 81        talking
# 82        talking
# 83        talking
# 84        talking
# 85        talking
#            ...
# 39286    reaching
# 39287    reaching
# 39288      makeup
# 39289      makeup
# 39290      makeup
# Name: class, Length: 18156, dtype: str

# %%
sns.histplot(data=df, y='class')
# Out:
# <Axes: xlabel='Count', ylabel='class'>

# %%
df.head(1)
# Out:
#                                          Ruta_Archivo  \
# 81  /mnt/c/Users/user/Documents/Alejandro_Mesa_Gom...
#
#                                      Video_Origen  ID_Accion        Actividad  \
# 81  gA_1_s1_2019-03-08T09;31;15+01;00_distraction          2  talking/talking
#
#     Frame_Inicio  Frame_Fin Actividad_    class
# 81           177        315    talking  talking

# %%
df['tupla'] = df.apply(lambda x : (x['Ruta_Archivo'],x['Video_Origen'],x['Frame_Inicio'],x['Frame_Inicio']), axis=1)

# %%
df.tupla.shape , len(np.unique(df.tupla))
# Out:
# ((18156,), 16534)
